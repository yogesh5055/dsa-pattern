# %%
s = 'abc123cd45ef67gh8'
current = []
j=0
while  j < len(s): 
      emp=''
      while j < len(s) and s[j].isdigit():
        emp+=s[j]
        j+=1
       
      if emp:
         current.append(list(emp))
      j+=1

ans = 0
check = 0


while check < len(current)-1:
    if current[check][-1] != current[check+1][0] :
        ans+=1
    check+=1
print(ans)
print("not working")
# Out:
# 3

# %% [markdown]
# THIS IS A MARKDOWN CELL
